# %%
from kafka import KafkaConsumer

consumer = KafkaConsumer(
    'orders-topic',
    bootstrap_servers='localhost:9092',
    auto_offset_reset='earliest'
)

for message in consumer:
    print("Processing Order:", message.value.decode())
# Out:
# Processing Order: OrderID:101 Product:Laptop
# Processing Order: OrderId:102 Product:Phone
# Processing Order: OrderID:103 Product:Headphones
# Processing Order: OrderID:101 Product:Laptop
# Processing Order: OrderId:102 Product:Phone
# Processing Order: OrderID:103 Product:Headphones
# Processing Order: OrderID:101 Product:Laptop
# Processing Order: OrderId:102 Product:Phone
# Processing Order: OrderID:103 Product:Headphones
# Processing Order: OrderID:101 Product:Laptop
# Processing Order: OrderId:102 Product:Phone
# Processing Order: OrderID:103 Product:Headphones
# Processing Order: OrderID:104 Product:charger
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 9
#       1 from kafka import KafkaConsumer
#       3 consumer = KafkaConsumer(
#       4     'orders-topic',
#       5     bootstrap_servers='localhost:9092',
# ...
