# %%
from kafka import KafkaConsumer

consumer = KafkaConsumer(
    'ride-topic',
    bootstrap_servers='localhost:9092'
)

for message in consumer:
    print("Ride Update:", message.value.decode())
# Out:
# Ride Update: Ride booked by User1
# Ride Update: Driver assigned
# Ride Update: Ride started
# Ride Update: Ride completed
