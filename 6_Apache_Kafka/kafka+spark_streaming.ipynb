# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("KafkaSparkStreaming") \
    .getOrCreate()

df = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", "test-topic") \
    .load()

df.selectExpr("CAST(value AS STRING)").writeStream \
    .format("console") \
    .start() \
    .awaitTermination()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[1], line 11
#       1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .appName("KafkaSparkStreaming") \
#       5     .getOrCreate()
#       7 df = spark.readStream \
#       8     .format("kafka") \
#       9     .option("kafka.bootstrap.servers", "localhost:9092") \
#      10     .option("subscribe", "test-topic") \
# ---> 11     .load()
#      13 df.selectExpr("CAST(value AS STRING)").writeStream \
#      14     .format("console") \
#      15     .start() \
#      16     .awaitTermination()
#
# File ~\anaconda3\Lib\site-packages\pyspark\sql\streaming\readwriter.py:307, in DataStreamReader.load(self, path, format, schema, **options)
#     305     return self._df(self._jreader.load(path))
#     306 else:
# --> 307     return self._df(self._jreader.load())
#
# File ~\anaconda3\Lib\site-packages\py4j\java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File ~\anaconda3\Lib\site-packages\pyspark\errors\exceptions\captured.py:269, in capture_sql_exception.<locals>.deco(*a, **kw)
#     265 converted = convert_exception(e.java_exception)
#     266 if not isinstance(converted, UnknownException):
#     267     # Hide where the exception came from that shows a non-Pythonic
#     268     # JVM exception message.
# --> 269     raise converted from None
#     270 else:
#     271     raise
#
# AnalysisException: Failed to find data source: kafka. Please deploy the application as per the deployment section of Structured Streaming + Kafka Integration Guide.
