# %%
from kafka import KafkaConsumer

consumer = KafkaConsumer(
    'attendance-topic',
    bootstrap_servers='localhost:9092'
)

for message in consumer:
    print("Recorded:", message.value.decode())
# Out:
# Recorded: Alice present
# Recorded: Bob present
# Recorded: Charlie present
