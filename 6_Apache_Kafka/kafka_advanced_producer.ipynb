# %%
from kafka import KafkaProducer

producer = KafkaProducer(bootstrap_servers='localhost:9092')

producer.send('multi-topic', b'Partition 0 message', partition=0)
producer.send('multi-topic', b'Partition 1 message', partition=1)
producer.send('multi-topic', b'Partition 2 message', partition=2)

producer.flush()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 6
#       3 producer = KafkaProducer(bootstrap_servers='localhost:9092')
#       5 producer.send('multi-topic', b'Partition 0 message', partition=0)
# ----> 6 producer.send('multi-topic', b'Partition 1 message', partition=1)
#       7 producer.send('multi-topic', b'Partition 2 message', partition=2)
#       9 producer.flush()
#
# File ~\anaconda3\Lib\site-packages\kafka\producer\kafka.py:855, in KafkaProducer.send(self, topic, value, key, headers, partition, timestamp_ms)
#     852     assert type(key_bytes) in (bytes, bytearray, memoryview, type(None))
#     853     assert type(value_bytes) in (bytes, bytearray, memoryview, type(None))
# --> 855     assigned_partition = self._partition(topic, partition, key, value,
#     856                                          key_bytes, value_bytes)
# ...
