# %% [markdown]
# Easy
#
# Create a simple pipeline with 3 tasks:
# 1️⃣ Load Data
# 2️⃣ Clean Data
# 3️⃣ Print Data
# 💻 Instructions
# Students must:
# ✔ Create 3 functions
# ✔ Call them in correct order
#
#
# Example structure
#
# def load():
#     print("Loading data")
#
# def clean():
#     print("Cleaning data")
#
# def print_data():
#     print("Displaying data")
#
# # pipeline
# load()
# clean()
# print_data()

# %%
# STEP 1 - Load
def load():
    print("Loading data")

# STEP 2 - Clean
def clean():
    print("Cleaning data")

# STEP 3 - Print
def print_data():
    print("Displaying data")

# PIPELINE
load()
clean()
print_data()
# Out:
# Loading data
# Cleaning data
# Displaying data
