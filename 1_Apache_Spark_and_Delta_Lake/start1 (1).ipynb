# %%
from pyspark.sql import SparkSession

# Create Spark session
spark = SparkSession.builder.appName("SparkExample").getOrCreate()

print("Spark is running")
# Out:
# Spark is running

# %%
data = [
    ("Alice", 25), 
    ("Bob", 30), 
    ("Charlie", 35)
    ]
df = spark.createDataFrame(data, ["Name", "Age"])
df.show()
# Out:
# +-------+---+
# |   Name|Age|
# +-------+---+
# |  Alice| 25|
# |    Bob| 30|
# |Charlie| 35|
# +-------+---+

# %%
df.select("Name").show()
# Out:
# +-------+
# |   Name|
# +-------+
# |  Alice|
# |    Bob|
# |Charlie|
# +-------+

# %%
df.filter(df.Age > 25).show()
# Out:
# +-------+---+
# |   Name|Age|
# +-------+---+
# |    Bob| 30|
# |Charlie| 35|
# +-------+---+

# %%
from pyspark.sql.functions import col
df2 = df.withColumn("AgeAfter5Years", col("Age") + 5)
df2.show()
# Out:
# +-------+---+--------------+
# |   Name|Age|AgeAfter5Years|
# +-------+---+--------------+
# |  Alice| 25|            30|
# |    Bob| 30|            35|
# |Charlie| 35|            40|
# +-------+---+--------------+

# %%
df.createOrReplaceTempView("students")
spark.sql("SELECT * FROM students WHERE Age > 25").show()
# Out:
# +-------+---+
# |   Name|Age|
# +-------+---+
# |    Bob| 30|
# |Charlie| 35|
# +-------+---+

# %%
df.orderBy("Age").show()
# Out:
# +-------+---+
# |   Name|Age|
# +-------+---+
# |  Alice| 25|
# |    Bob| 30|
# |Charlie| 35|
# +-------+---+

# %%
df.groupBy("Age").count().show()
# Out:
# +---+-----+
# |Age|count|
# +---+-----+
# | 25|    1|
# | 30|    1|
# | 35|    1|
# +---+-----+

# %%
df.count()
# Out:
# 3

# %%
df.take(3)   #1st 3 rows displayed
# Out:
# [Row(Name='Alice', Age=25),
#  Row(Name='Bob', Age=30),
#  Row(Name='Charlie', Age=35)]

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: long (nullable = true)

# %%
df.select("Name").show()
# Out:
# +-------+
# |   Name|
# +-------+
# |  Alice|
# |    Bob|
# |Charlie|
# +-------+

# %%
df.select("Name","Age").show()     # to select multiple cols
# Out:
# +-------+---+
# |   Name|Age|
# +-------+---+
# |  Alice| 25|
# |    Bob| 30|
# |Charlie| 35|
# +-------+---+

# %%
df3 = df.withColumnRenamed("Age","StudentAge")    # change col name

# %%
df3.show()
# Out:
# +-------+----------+
# |   Name|StudentAge|
# +-------+----------+
# |  Alice|        25|
# |    Bob|        30|
# |Charlie|        35|
# +-------+----------+
